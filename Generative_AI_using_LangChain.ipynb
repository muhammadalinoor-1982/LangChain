# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadalinoor-1982/LangChain/blob/main/Generative_AI_using_LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Generative AI using LangChain**
#
# Source Link: https://www.youtube.com/playlist?list=PLKnIA16_RmvaTbihpo4MtzVm4XOQa0ER0
#
# Source Link of Cariculum: https://www.youtube.com/watch?v=pSVk-5WemQ0
#
# Start from: 5/02/2025
#
# What is GenAI
#
# ![GENAIDef.JPG](data:image/jpeg;base64,...)
#
# Different types of GenAI:
#
# **`1. LangChain`**
#
# **`2. LLAMAIndex`**
#
# **`3. Haystack`**
#
# Road Map
#
# ![GENAI.JPG](data:image/jpeg;base64,...)
#
# LangChain
#
# ![LangChain.JPG](data:image/jpeg;base64,...)
#
# Fanda mental of LangChain
#
# ![Fanda.JPG](data:image/jpeg;base64,...)
#
# Road Map
#
# ![Fandaa.JPG](data:image/jpeg;base64,...)
#
# ![fandaaa.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #**Components of LangChain**
#
# ![Components of LangChain.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![Lang.jpg](data:image/jpeg;base64,...)
